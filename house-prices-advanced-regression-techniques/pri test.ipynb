# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns  
import numpy as np

# %%
tt_df=pd.read_csv("test.csv")
tt_df.head(3)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     1Story            5            6       1961
# 1       Norm     1Fam     1Story            6            6       1958
# 2       Norm     1Fam     2Story            5            5       1997
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# ...

# %%
tt_df.shape
# Out:
# (1459, 80)

# %%
# show the all row and column 
pd.options.display.max_rows

# %%
tt_df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            4
# LotFrontage       227
# LotArea             0
# Street              0
# Alley            1352
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType        894
# MasVnrArea         15
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           44
# BsmtCond           45
# BsmtExposure       44
# BsmtFinType1       42
# BsmtFinSF1          1
# BsmtFinType2       42
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# Heating             0
# HeatingQC           0
# ...

# %%
tt_df["LotFrontage"]=tt_df["LotFrontage"].fillna(tt_df["LotFrontage"].mean())
tt_df["BsmtQual"]=tt_df["BsmtQual"].fillna(tt_df["BsmtQual"].mode()[0])
tt_df["BsmtCond"]=tt_df["BsmtCond"].fillna(tt_df["BsmtCond"].mode()[0]) 
tt_df["FireplaceQu"]=tt_df["FireplaceQu"].fillna(tt_df["FireplaceQu"].mode()[0])
tt_df["GarageType"]=tt_df["GarageType"].fillna(tt_df["GarageType"].mode()[0])
tt_df["GarageFinish"]=tt_df["GarageFinish"].fillna(tt_df["GarageFinish"].mode()[0])
tt_df["GarageQual"]=tt_df["GarageQual"].fillna(tt_df["GarageQual"].mode()[0])
tt_df["GarageCond"]=tt_df["GarageCond"].fillna(tt_df["GarageCond"].mode()[0])
tt_df["MasVnrType"]=tt_df["MasVnrType"].fillna(tt_df["MasVnrType"].mode()[0])
tt_df["MasVnrArea"]=tt_df["MasVnrArea"].fillna(tt_df["MasVnrArea"].mode()[0])
tt_df['MSZoning']=tt_df['MSZoning'].fillna(tt_df['MSZoning'].mode()[0])

# %%
tt_df.drop(['Alley','GarageYrBlt','PoolQC','Fence','MiscFeature','Id'],axis=1,inplace=True)

# %%
sns.heatmap(tt_df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
tt_df["BsmtExposure"]=tt_df["BsmtExposure"].fillna(tt_df["BsmtExposure"].mode()[0])
tt_df["BsmtFinType2"]=tt_df["BsmtFinType2"].fillna(tt_df["BsmtFinType2"].mode()[0])

# %%
sns.heatmap(tt_df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
tt_df.shape
# Out:
# (1459, 74)

# %%
tt_df.loc[:, tt_df.isnull().any()].head()
# Out:
#   Utilities Exterior1st Exterior2nd BsmtFinType1  BsmtFinSF1  BsmtFinSF2  \
# 0    AllPub     VinylSd     VinylSd          Rec       468.0       144.0
# 1    AllPub     Wd Sdng     Wd Sdng          ALQ       923.0         0.0
# 2    AllPub     VinylSd     VinylSd          GLQ       791.0         0.0
# 3    AllPub     VinylSd     VinylSd          GLQ       602.0         0.0
# 4    AllPub     HdBoard     HdBoard          ALQ       263.0         0.0
#
#    BsmtUnfSF  TotalBsmtSF  BsmtFullBath  BsmtHalfBath KitchenQual Functional  \
# 0      270.0        882.0           0.0           0.0          TA        Typ
# 1      406.0       1329.0           0.0           0.0          Gd        Typ
# 2      137.0        928.0           0.0           0.0          TA        Typ
# 3      324.0        926.0           0.0           0.0          Gd        Typ
# 4     1017.0       1280.0           0.0           0.0          Gd        Typ
#
#    GarageCars  GarageArea SaleType
# ...

# %%
tt_df['Utilities']=tt_df['Utilities'].fillna(tt_df['Utilities'].mode()[0])
tt_df['Exterior1st']=tt_df['Exterior1st'].fillna(tt_df['Exterior1st'].mode()[0])
tt_df['Exterior2nd']=tt_df['Exterior2nd'].fillna(tt_df['Exterior2nd'].mode()[0])
tt_df['BsmtFinType1']=tt_df['BsmtFinType1'].fillna(tt_df['BsmtFinType1'].mode()[0])
tt_df['BsmtFinSF1']=tt_df['BsmtFinSF1'].fillna(tt_df['BsmtFinSF1'].mean())
tt_df['BsmtFinSF2']=tt_df['BsmtFinSF2'].fillna(tt_df['BsmtFinSF2'].mean())
tt_df['BsmtUnfSF']=tt_df['BsmtUnfSF'].fillna(tt_df['BsmtUnfSF'].mean())
tt_df['TotalBsmtSF']=tt_df['TotalBsmtSF'].fillna(tt_df['TotalBsmtSF'].mean())
tt_df['BsmtFullBath']=tt_df['BsmtFullBath'].fillna(tt_df['BsmtFullBath'].mode()[0])
tt_df['BsmtHalfBath']=tt_df['BsmtHalfBath'].fillna(tt_df['BsmtHalfBath'].mode()[0])
tt_df['KitchenQual']=tt_df['KitchenQual'].fillna(tt_df['KitchenQual'].mode()[0])
tt_df['Functional']=tt_df['Functional'].fillna(tt_df['Functional'].mode()[0])
tt_df['GarageCars']=tt_df['GarageCars'].fillna(tt_df['GarageCars'].mean())
tt_df['GarageArea']=tt_df['GarageArea'].fillna(tt_df['GarageArea'].mean())
tt_df['SaleType']=tt_df['SaleType'].fillna(tt_df['SaleType'].mode()[0])

# %%
tt_df.shape
# Out:
# (1459, 74)

# %%
tt_df.to_csv('formulatedtest.csv',index=False)
